# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.left = None
        self.right = None
        self.height = None

# %%
class Tree:
    def createNode(self,value):
        return Node(value)
    
    def insertNode(Self,root,value):
        if root is None:
            return self.createNode(value)
        if root.value > value:
            root.left = self.insertNode(root.left,value)
        else:
            root.right = self.insertNode(root.right,value)
        return root
    
    def leftView(self,root):
        hashmap = {}
        q = []
        q.append(root)
        root.height = 0
        while len(q):
            node = q.pop(0)
            if node.height not in hashmap:
                hashmap[node.height] = node.value
            if node.left:
                node.left.height = node.height + 1
                q.append(node.left)
            if node.right:
                node.right.height = node.height + 1
                q.append(node.right)
        for key in sorted(hashmap):
            print(hashmap[key])
    
    def rightview(self,value):
        hashmap = {}
        q = []
        q.append(root)
        root.height = 0
        while len(q):
            node = q.pop(0)
            hashmap[node.height] = node.value
            if node.left:
                node.left.height = node.height + 1
                q.append(node.left)
            if node.right:
                node.right.height = node.height + 1
                q.append(node.right)
        for key in sorted(hashmap):
            print(hashmap[key])
    r
    def rightViewRecursive(self,root):
        retList = []
        level = 0
        
        def rVRhelper(root,level):
            if root is None:
                return
            if level == len(retList):
                retList.append(root.value)
            if root.right:
                rVRhelper(root.right,level+1)
            if root.left:
                rVRhelper(root.left,level+1)
